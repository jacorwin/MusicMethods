# %% [markdown]
# # Load Libraries

# %%
import json
import os
import subprocess
import glob

# %%
json_file = "/Users/jcorwin/Desktop/MusicTemp/json_files/Lisa MixTape 01.json"
with open(json_file) as f:
   data = json.load(f)

data
# Out:
# {'ALBUM': "Lisa's MixTape 01",
#  'ALBUMARTIST': 'Various Artists',
#  'MUSICBRAINZ_ALBUMARTIST': 'Various Artists',
#  'GENRE': 'None',
#  'Songs': {'01': {'TRACKNUMBER': 1,
#    'ARTIST': 'Greatful Dead',
#    'TITLE': 'Sugar Magnolia'},
#   '02': {'TRACKNUMBER': 2,
#    'ARTIST': 'The Beatles',
#    'TITLE': 'Twist and Shout'},
#   '03': {'TRACKNUMBER': 3, 'ARTIST': 'Radiohead', 'TITLE': 'Lift'},
#   '04': {'TRACKNUMBER': 4,
#    'ARTIST': 'John Lennon & Yoko Ono',
#    'TITLE': 'Give Peace a Chance'},
#   '05': {'TRACKNUMBER': 5,
#    'ARTIST': 'Greatful Dead',
#    'TITLE': 'The Golden Road'},
#   '06': {'TRACKNUMBER': 6,
#    'ARTIST': 'Elliot Smith',
#    'TITLE': 'Somebody That I Used To Know'},
#   '07': {'TRACKNUMBER': 7, 'ARTIST': 'Radiohead', 'TITLE': 'Blow Out'},
#   '08': {'TRACKNUMBER': 8, 'ARTIST': 'Greatful Dead', 'TITLE': 'Casey Jones'},
#   '09': {'TRACKNUMBER': 9, 'ARTIST': 'The Beatles', 'TITLE': 'Revolution'},
#   '10': {'TRACKNUMBER': 10,
#    'ARTIST': 'The Dave Brubeck Quartet',
#    'TITLE': 'Take Five'},
#   '11': {'TRACKNUMBER': 11, 'ARTIST': 'Radiohead', 'TITLE': 'Idioteque'},
#   '12': {'TRACKNUMBER': 12,
#    'ARTIST': 'Radiohead',
#    'TITLE': 'The National Anthem'},
#   '13': {'TRACKNUMBER': 13,
#    'ARTIST': 'John Lennon & Yoko Ono',
#    'TITLE': 'Imagine'},
#   '14': {'TRACKNUMBER': 14, 'ARTIST': 'The Beatles', 'TITLE': 'In My Life'},
#   '15': {'TRACKNUMBER': 15,
#    'ARTIST': 'Greatful Dead',
#    'TITLE': "Uncle John's Band"},
#   '16': {'TRACKNUMBER': 16,
#    'ARTIST': 'The Buggles',
#    'TITLE': 'Video Killed the Radio Star'},
#   '17': {'TRACKNUMBER': 17, 'ARTIST': 'Soul Coughing', 'TITLE': 'Soft Serve'},
#   '18': {'TRACKNUMBER': 18,
#    'ARTIST': 'John Lennon & Yoko Ono',
#    'TITLE': 'Watching the Wheels'}}}

# %%
file = '/Users/jcorwin/Desktop/MusicTemp/MixTapes/Lisa MixTape 01/02 - Track 2.flac'
mixtape_bool = True


def mod_song_meta_data(data: dict, file: str, mixtape_bool: bool):
    file_name = file.split('/')[-1]
    track_number = file_name.split(' - ')[0]
    print(file_name)
    print(data['Songs'][track_number]['ARTIST'])

    #Album
    tag_album = data['ALBUM']
    cmd_album = [
                'metaflac',
                '--remove-tag=ALBUM',
                '--set-tag=ALBUM=' + tag_album,
                file
                ]

    #AlbumArtist
    tag_alb_art = data['ALBUMARTIST']
    cmd_alb_art = [
                'metaflac',
                '--remove-tag=ALBUMARTIST',
                '--set-tag=ALBUMARTIST=' + tag_alb_art,
                file
                ]

    #MUSICBRAINZ_ALBUMARTIST
    tag_muscbrnz_alb_art = data['MUSICBRAINZ_ALBUMARTIST']
    cmd_muscbrnz_alb_art = [
                'metaflac',
                '--remove-tag=MUSICBRAINZ_ALBUMARTIST',
                '--set-tag=MUSICBRAINZ_ALBUMARTIST=' + tag_muscbrnz_alb_art,
                file
                ]

    #ARTIST
    if mixtape_bool:
        tag_art = data['Songs'][track_number]['ARTIST']
    else:
        tag_art = data['ARTIST']
    cmd_art = [
                'metaflac',
                '--remove-tag=ARTIST',
                '--set-tag=ARTIST=' + tag_art,
                file
                ]

    #TRACKNUMBER
    tag_trknum = str(data['Songs'][track_number]['TRACKNUMBER'])
    cmd_trknum = [
                'metaflac',
                '--remove-tag=TRACKNUMBER',
                '--set-tag=TRACKNUMBER=' + tag_trknum,
                file
                ]

    #TITLE
    tag_title = data['Songs'][track_number]['TITLE']
    cmd_title = [
                'metaflac',
                '--remove-tag=TITLE',
                '--set-tag=TITLE=' + tag_title,
                file
                ]

    #GENRE
    tag_genre = data['GENRE']
    cmd_genre = [
                'metaflac',
                '--remove-tag=GENRE',
                '--set-tag=GENRE=' + tag_genre,
                file
                ]

    # Run the commands to process the files
    out_album = subprocess.run(cmd_album, 
                            capture_output=True)
    out_alb_art = subprocess.run(cmd_alb_art, 
                                capture_output=True)
    out_muscbrnz_alb_art = subprocess.run(cmd_muscbrnz_alb_art, 
                                        capture_output=True)
    out_art = subprocess.run(cmd_art, 
                            capture_output=True)
    out_trknum = subprocess.run(cmd_trknum, 
                                capture_output=True)
    out_title = subprocess.run(cmd_title, 
                            capture_output=True)
    out_genre = subprocess.run(cmd_genre, 
                            capture_output=True)

    #Change file Name
    file_path = file.split('/')
    file_path.pop()

    file_name_new = track_number + ' - ' + tag_title + '.flac'
    file_new = '/'.join(file_path) + '/' + file_name_new

    os.rename(file, file_new)

    return file_new #Could add a dictionary of subprocess outs.


#mod_song_meta_data(data, file, mixtape_bool)

# %%
# Out:
# 01 - Sugar Magnolia.flac  07 - Track 7.flac         13 - Track 13.flac
# 02 - Twist and Shout.flac 08 - Track 8.flac         14 - Track 14.flac
# 03 - Track 3.flac         09 - Track 9.flac         15 - Track 15.flac
# 04 - Track 4.flac         10 - Track 10.flac        16 - Track 16.flac
# 05 - Track 5.flac         11 - Track 11.flac        17 - Track 17.flac
# 06 - Track 6.flac         12 - Track 12.flac        18 - Track 18.flac

# %%
flac_dir = '/Users/jcorwin/Desktop/MusicTemp/MixTapes/Lisa MixTape 01/'
mixtape_bool = True

new_files = []
for i in glob.glob(flac_dir + '*.flac'):
    file_name = i.split('/')[-1]
    print(file_name)
    new_files.append(mod_song_meta_data(data, i, mixtape_bool))


print(new_files)
# Out:
# 03 - Track 3.flac
# 03 - Track 3.flac
# Radiohead
# 08 - Track 8.flac
# 08 - Track 8.flac
# Greatful Dead
# 10 - Track 10.flac
# 10 - Track 10.flac
# The Dave Brubeck Quartet
# 12 - Track 12.flac
# 12 - Track 12.flac
# Radiohead
# 09 - Track 9.flac
# 09 - Track 9.flac
# The Beatles
# 16 - Track 16.flac
# 16 - Track 16.flac
# The Buggles
# 14 - Track 14.flac
# 14 - Track 14.flac
# The Beatles
# 02 - Twist and Shout.flac
# 02 - Twist and Shout.flac
# The Beatles
# 17 - Track 17.flac
# 17 - Track 17.flac
# Soul Coughing
# 15 - Track 15.flac
# 15 - Track 15.flac
# Greatful Dead
# 11 - Track 11.flac
# 11 - Track 11.flac
# Radiohead
# 13 - Track 13.flac
# 13 - Track 13.flac
# John Lennon & Yoko Ono
# 04 - Track 4.flac
# 04 - Track 4.flac
# John Lennon & Yoko Ono
# 05 - Track 5.flac
# 05 - Track 5.flac
# Greatful Dead
# 18 - Track 18.flac
# 18 - Track 18.flac
# John Lennon & Yoko Ono
# 06 - Track 6.flac
# 06 - Track 6.flac
# Elliot Smith
# 07 - Track 7.flac
# 07 - Track 7.flac
# Radiohead
# 01 - Sugar Magnolia.flac
# 01 - Sugar Magnolia.flac
# Greatful Dead
# ['/Users/jcorwin/Desktop/MusicTemp/MixTapes/Lisa MixTape 01/03 - Lift.flac', '/Users/jcorwin/Desktop/MusicTemp/MixTapes/Lisa MixTape 01/08 - Casey Jones.flac', '/Users/jcorwin/Desktop/MusicTemp/MixTapes/Lisa MixTape 01/10 - Take Five.flac', '/Users/jcorwin/Desktop/MusicTemp/MixTapes/Lisa MixTape 01/12 - The National Anthem.flac', '/Users/jcorwin/Desktop/MusicTemp/MixTapes/Lisa MixTape 01/09 - Revolution.flac', '/Users/jcorwin/Desktop/MusicTemp/MixTapes/Lisa MixTape 01/16 - Video Killed the Radio Star.flac', '/Users/jcorwin/Desktop/MusicTemp/MixTapes/Lisa MixTape 01/14 - In My Life.flac', '/Users/jcorwin/Desktop/MusicTemp/MixTapes/Lisa MixTape 01/02 - Twist and Shout.flac', '/Users/jcorwin/Desktop/MusicTemp/MixTapes/Lisa MixTape 01/17 - Soft Serve.flac', "/Users/jcorwin/Desktop/MusicTemp/MixTapes/Lisa MixTape 01/15 - Uncle John's Band.flac", '/Users/jcorwin/Desktop/MusicTemp/MixTapes/Lisa MixTape 01/11 - Idioteque.flac', '/Users/jcorwin/Desktop/MusicTemp/MixTapes/Lisa MixTape 01/13 - Imagine.flac', '/Users/jcorwin/Desktop/MusicTemp/MixTapes/Lisa MixTape 01/04 - Give Peace a Chance.flac', '/Users/jcorwin/Desktop/MusicTemp/MixTapes/Lisa MixTape 01/05 - The Golden Road.flac', '/Users/jcorwin/Desktop/MusicTemp/MixTapes/Lisa MixTape 01/18 - Watching the Wheels.flac', '/Users/jcorwin/Desktop/MusicTemp/MixTapes/Lisa MixTape 01/06 - Somebody That I Used To Know.flac', '/Users/jcorwin/Desktop/MusicTemp/MixTapes/Lisa MixTape 01/07 - Blow Out.flac', '/Users/jcorwin/Desktop/MusicTemp/MixTapes/Lisa MixTape 01/01 - Sugar Magnolia.flac']

# %%
# !ls /Users/jcorwin/Desktop/MusicTemp/MixTapes/Lisa\ MixTape\ 01/
# Out:
# 01 - Sugar Magnolia.flac               10 - Take Five.flac
# 02 - Twist and Shout.flac              11 - Idioteque.flac
# 03 - Lift.flac                         12 - The National Anthem.flac
# 04 - Give Peace a Chance.flac          13 - Imagine.flac
# 05 - The Golden Road.flac              14 - In My Life.flac
# 06 - Somebody That I Used To Know.flac 15 - Uncle John's Band.flac
# 07 - Blow Out.flac                     16 - Video Killed the Radio Star.flac
# 08 - Casey Jones.flac                  17 - Soft Serve.flac
# 09 - Revolution.flac                   18 - Watching the Wheels.flac

# %%
# !metaflac --list /Users/jcorwin/Desktop/MusicTemp/MixTapes/Lisa\ MixTape\ 01/15\ -\ Uncle\ John\'s\ Band.flac | grep comment
# Out:
#   comments: 13
#     comment[0]: REPLAYGAIN_ALBUM_PEAK=1.00000000
#     comment[1]: ENCODER=NADserver
#     comment[2]: REPLAYGAIN_ALBUM_GAIN=-2.31 dB
#     comment[3]: REPLAYGAIN_TRACK_PEAK=1.00000000
#     comment[4]: REPLAYGAIN_REFERENCE_LOUDNESS=89.0 dB
#     comment[5]: REPLAYGAIN_TRACK_GAIN=-2.31 dB
#     comment[6]: ALBUM=Lisa's MixTape 01
#     comment[7]: ALBUMARTIST=Various Artists
#     comment[8]: MUSICBRAINZ_ALBUMARTIST=Various Artists
#     comment[9]: ARTIST=Greatful Dead
#     comment[10]: TRACKNUMBER=15
#     comment[11]: TITLE=Uncle John's Band
#     comment[12]: GENRE=None
